# %% [markdown]
# # Test MP Data - B.E MOULOUD
# ---

# %% [markdown]
# # Exploratory Data analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("./Test_Data_Science/Test_Data_Science/nba_logreg.csv")
data = df.copy()

# %%
data.duplicated().sum()
# Out:
# 12

# %%
data.drop_duplicates(inplace=True, ignore_index=True)

# %%
data.drop(columns=["Name"], inplace=True)

# %%
data["TARGET_5Yrs"].value_counts(normalize=True)
# Out:
# TARGET_5Yrs
# 1.0    0.620482
# 0.0    0.379518
# Name: proportion, dtype: float64

# %%
data.head()
# Out:
#    GP   MIN  PTS  FGM  FGA   FG%  3P Made  3PA   3P%  FTM  FTA   FT%  OREB  \
# 0  36  27.4  7.4  2.6  7.6  34.7      0.5  2.1  25.0  1.6  2.3  69.9   0.7
# 1  35  26.9  7.2  2.0  6.7  29.6      0.7  2.8  23.5  2.6  3.4  76.5   0.5
# 2  74  15.3  5.2  2.0  4.7  42.2      0.4  1.7  24.4  0.9  1.3  67.0   0.5
# 3  58  11.6  5.7  2.3  5.5  42.6      0.1  0.5  22.6  0.9  1.3  68.9   1.0
# 4  48  11.5  4.5  1.6  3.0  52.4      0.0  0.1   0.0  1.3  1.9  67.4   1.0
#
#    DREB  REB  AST  STL  BLK  TOV  TARGET_5Yrs
# 0   3.4  4.1  1.9  0.4  0.4  1.3          0.0
# 1   2.0  2.4  3.7  1.1  0.5  1.6          0.0
# 2   1.7  2.2  1.0  0.5  0.3  1.0          0.0
# 3   0.9  1.9  0.8  0.6  0.1  1.0          1.0
# 4   1.5  2.5  0.3  0.3  0.4  0.8          1.0

# %%
data.shape
# Out:
# (1328, 20)

# %%
data.dtypes
# Out:
# GP               int64
# MIN            float64
# PTS            float64
# FGM            float64
# FGA            float64
# FG%            float64
# 3P Made        float64
# 3PA            float64
# 3P%            float64
# FTM            float64
# FTA            float64
# FT%            float64
# OREB           float64
# DREB           float64
# REB            float64
# AST            float64
# STL            float64
# BLK            float64
# TOV            float64
# TARGET_5Yrs    float64
# dtype: object

# %%
data.isna().sum()
# Out:
# GP              0
# MIN             0
# PTS             0
# FGM             0
# FGA             0
# FG%             0
# 3P Made         0
# 3PA             0
# 3P%            10
# FTM             0
# FTA             0
# FT%             0
# OREB            0
# DREB            0
# REB             0
# AST             0
# STL             0
# BLK             0
# TOV             0
# TARGET_5Yrs     0
# dtype: int64

# %%
data[data["3P%"].isna()]
# Out:
#      GP   MIN   PTS  FGM  FGA   FG%  3P Made  3PA  3P%  FTM  FTA   FT%  OREB  \
# 334  64  12.7   4.1  1.8  3.3  52.8      0.0  0.0  NaN  0.6  1.3  43.5   1.4
# 335  53  10.8   2.8  1.3  2.1  60.4      0.0  0.0  NaN  0.3  0.8  42.5   0.9
# 353  79  24.7  10.6  4.6  9.0  51.1      0.0  0.0  NaN  1.4  1.8  78.4   2.0
# 379  60  11.9   3.2  1.2  2.4  48.6      0.0  0.0  NaN  0.8  1.1  75.8   0.7
# 390  39   6.9   1.3  0.5  1.3  41.2      0.0  0.0  NaN  0.3  0.5  50.0   0.5
# 499  59  18.2   6.1  2.6  4.7  55.6      0.0  0.0  NaN  0.8  1.5  55.1   1.5
# 501  63  17.2   5.3  2.2  4.7  46.1      0.0  0.0  NaN  1.0  1.7  58.3   1.5
# 502  71  17.0   4.9  2.1  4.2  50.3      0.0  0.0  NaN  0.7  1.0  70.8   1.5
# 513  72  11.9   2.9  1.2  2.3  50.9      0.0  0.0  NaN  0.5  1.2  45.9   1.0
# 551  56  18.9   4.7  2.1  4.6  45.0      0.0  0.0  NaN  0.5  0.7  67.5   1.1
#
#      DREB  REB  AST  STL  BLK  TOV  TARGET_5Yrs
# 334   2.4  3.8  0.3  0.2  0.3  0.9          0.0
# 335   1.9  2.8  0.3  0.4  0.4  0.4          0.0
# 353   3.8  5.7  0.5  0.5  1.1  1.5          1.0
# 379   1.7  2.5  0.5  0.2  0.5  1.2          1.0
# 390   1.5  1.9  0.3  0.2  0.3  0.4          0.0
# 499   3.7  5.2  0.6  0.8  1.3  1.1          0.0
# 501   3.2  4.7  1.0  0.3  1.3  0.9          1.0
# 502   2.1  3.6  0.7  0.6  0.3  0.8          1.0
# 513   1.5  2.5  0.6  0.3  0.7  0.7          0.0
# 551   3.8  4.9  0.7  0.6  0.8  1.1          1.0

# %%
data.dropna()["TARGET_5Yrs"].value_counts(normalize=True)
# Out:
# TARGET_5Yrs
# 1.0    0.621396
# 0.0    0.378604
# Name: proportion, dtype: float64

# %%
feature_columns = data.columns[:-1]

# %%
for col in feature_columns:
    fig, (ax1, ax2) = plt.subplots(1,2, figsize=[12,8])
    sns.histplot(data=data, x = col, stat='density', kde=True, ax=ax1)
    sns.boxplot(data[col], ax=ax2)

# %%
data[data["MIN"] == data["MIN"].min()]
# Out:
#      GP  MIN  PTS  FGM  FGA   FG%  3P Made  3PA   3P%  FTM  FTA  FT%  OREB  \
# 800  14  3.1  1.1  0.4  1.6  26.1      0.2  0.9  23.1  0.0  0.0  0.0   0.0
#
#      DREB  REB  AST  STL  BLK  TOV  TARGET_5Yrs
# 800   0.4  0.4  0.1  0.0  0.2  0.3          0.0

# %%
data[data["MIN"] == data["MIN"].max()]
# Out:
#       GP   MIN   PTS  FGM   FGA   FG%  3P Made  3PA   3P%  FTM  FTA   FT%  \
# 1179  70  40.9  19.0  6.9  16.1  42.6      1.9  4.8  39.5  3.4  4.2  79.7
#
#       OREB  DREB  REB  AST  STL  BLK  TOV  TARGET_5Yrs
# 1179   0.8   3.2  4.0  9.3  1.4  0.3  3.8          1.0

# %%
for col in feature_columns:
    plt.figure()
    sns.histplot(data=data, x = col, hue = "TARGET_5Yrs", stat='density', kde=True)

# %% [markdown]
# ## Relations Variable/Variable

# %%
# sns.pairplot(data[data.columns[:-1]])

# %%
plt.figure(figsize=[10,8])
sns.heatmap(data[data.columns[:-1]].corr())
plt.plot(range(len(data.columns)), range(len(data.columns)), c='r')

# %%
plt.figure(figsize=[5,4])
sns.clustermap(data[data.columns[:-1]].corr(), annot=True)

# %% [markdown]
# ## Analyse aspects defensif vs offensif

# %%
defensive_variables = ['OREB', 'DREB', 'REB', 'STL', 'BLK', 'TOV']
offensive_variables = ['PTS', 'FGM', 'FGA', 'FG%', '3P Made', '3PA', '3P%', 'FTM', 'FTA', 'FT%', "AST"]
time_variables = ["GP", "MIN"]

# %%
for var in defensive_variables:
    fig, (ax1, ax2) = plt.subplots(1,2, figsize=[12,5])
    sns.histplot(data=data, x = var, hue = "TARGET_5Yrs", stat='density', kde=True, ax=ax1)
    sns.boxplot(data=data, y = var, hue = "TARGET_5Yrs", ax=ax2)

# %%
for var in offensive_variables:
    fig, (ax1, ax2) = plt.subplots(1,2, figsize=[12,5])
    sns.histplot(data=data, x = var, hue = "TARGET_5Yrs", stat='density', kde=True, ax=ax1)
    sns.boxplot(data=data, y = var, hue = "TARGET_5Yrs", ax=ax2)

# %% [markdown]
# ## Tests statistique

# %%
from scipy.stats import ttest_ind

# %%
test_data = data.copy()
test_data.dropna(inplace=True)
more_than_5_years_data = test_data[test_data["TARGET_5Yrs"] == 1.]
less_than_5_years_data = test_data[test_data["TARGET_5Yrs"] == 0.]

# %%
less_than_5_years_data.shape
# Out:
# (499, 20)

# %%
more_than_5_years_data.shape
# Out:
# (819, 20)

# %%
def t_test(col):
    alpha = 0.01
    _, p = ttest_ind(more_than_5_years_data.sample(less_than_5_years_data.shape[0])[col], less_than_5_years_data[col])
    if p < alpha:
        return 'HO rejetée'
    else:
        return 'H0'

# %%
for col in test_data.columns[:-1]:
    test_result = t_test(col)
    print(f"{col :-<50}  {test_result}")
# Out:
# GP------------------------------------------------  HO rejetée
# MIN-----------------------------------------------  HO rejetée
# PTS-----------------------------------------------  HO rejetée
# FGM-----------------------------------------------  HO rejetée
# FGA-----------------------------------------------  HO rejetée
# FG%-----------------------------------------------  HO rejetée
# 3P Made-------------------------------------------  H0
# 3PA-----------------------------------------------  H0
# 3P%-----------------------------------------------  H0
# FTM-----------------------------------------------  HO rejetée
# FTA-----------------------------------------------  HO rejetée
# FT%-----------------------------------------------  HO rejetée
# OREB----------------------------------------------  HO rejetée
# DREB----------------------------------------------  HO rejetée
# REB-----------------------------------------------  HO rejetée
# AST-----------------------------------------------  HO rejetée
# STL-----------------------------------------------  HO rejetée
# BLK-----------------------------------------------  HO rejetée
# TOV-----------------------------------------------  HO rejetée

# %% [markdown]
# # Pre-Processing

# %%
data = df.copy()

data.drop_duplicates(inplace=True, ignore_index=True)
data.drop(columns=["Name"], inplace=True)

# %%
data.shape
# Out:
# (1328, 20)

# %%
data["TARGET_5Yrs"].value_counts(normalize=True)
# Out:
# TARGET_5Yrs
# 1.0    0.620482
# 0.0    0.379518
# Name: proportion, dtype: float64

# %%
defensive_variables = ['OREB', 'DREB', 'REB', 'STL', 'BLK', 'TOV']
offensive_variables = ['PTS', 'FGM', 'FGA', 'FG%', '3P Made', '3PA', '3P%', 'FTM', 'FTA', 'FT%', "AST"]
time_variables = ["GP", "MIN"]

# %% [markdown]
# ## Minimum Pre-Processing

# %% [markdown]
# ### Train test split

# %%
from sklearn.model_selection import train_test_split

# %%
train_set, test_set = train_test_split(data, test_size=0.2, random_state=0)

# %%
train_set["TARGET_5Yrs"].value_counts(normalize=True)
# Out:
# TARGET_5Yrs
# 1.0    0.620527
# 0.0    0.379473
# Name: proportion, dtype: float64

# %%
test_set["TARGET_5Yrs"].value_counts(normalize=True)
# Out:
# TARGET_5Yrs
# 1.0    0.620301
# 0.0    0.379699
# Name: proportion, dtype: float64

# %% [markdown]
# **On garde a peu pres les memes proportion donc c'est bien**

# %% [markdown]
# ### Pre-Processing of data

# %%
def imputation(df): 
    
    return df.dropna(axis=0)


def feature_engineering(df):
    
    df.drop(["FGM", "FTM", "STL"], axis=1, inplace=True)
    
    return df
    
def preprocessing(df, target_name):

    df = imputation(df)
    df = feature_engineering(df)

    X = df.drop(target_name, axis=1)
    y = df[target_name]

    return X, y

# %%
X_train, y_train = preprocessing(train_set, "TARGET_5Yrs")
X_test, y_test = preprocessing(test_set, "TARGET_5Yrs")

# %%
X_train_columns = X_train.columns

# %%
X_train.head()
# Out:
#       GP   MIN  PTS  FGA   FG%  3P Made  3PA   3P%  FTA   FT%  OREB  DREB  \
# 1161  64  15.3  3.9  3.6  43.7      0.1  0.3  40.9  1.0  64.6   0.5   1.0
# 567   44  11.0  4.9  5.1  41.8      0.0  0.1  16.7  0.9  66.7   1.1   1.9
# 1269  81  21.9  5.8  5.0  47.9      0.0  0.0   0.0  1.3  72.9   3.7   3.8
# 49    56   9.6  3.4  3.0  45.6      0.0  0.1   0.0  1.0  65.5   0.5   0.8
# 589   60  20.7  7.9  5.7  60.8      0.0  0.0  50.0  2.7  37.1   2.8   4.8
#
#       REB  AST  BLK  TOV
# 1161  1.5  2.4  0.2  1.6
# 567   3.0  0.2  0.1  0.7
# 1269  7.5  1.2  0.4  1.2
# 49    1.2  1.1  0.2  0.8
# 589   7.6  0.5  1.6  0.9

# %%
defensive_variables = ['OREB', 'DREB', 'REB', 'BLK', 'TOV']
defensive_indices = {col: X_train.columns.get_loc(col) for col in defensive_variables}

offensive_variables = ['PTS', 'FGA', 'FG%', '3P Made', '3PA', '3P%', 'FTA', 'FT%', "AST"]
offensive_indices = {col: X_train.columns.get_loc(col) for col in offensive_variables}

time_variables = ["GP", "MIN"]
time_indices = {col: X_train.columns.get_loc(col) for col in time_variables}

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.compose import ColumnTransformer
from sklearn.feature_selection import f_classif, SelectKBest
from sklearn.pipeline import make_pipeline, make_union
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.decomposition import PCA

# %%
scaler = StandardScaler()
prep_step_model = make_pipeline(scaler, RandomForestClassifier(max_depth=3, random_state=0))
prep_step_model
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(max_depth=3, random_state=0))])

# %% [markdown]
# ## Procedure d'evaluation

# %%
from sklearn.metrics import f1_score, confusion_matrix, classification_report
from sklearn.model_selection import learning_curve
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display
from sklearn.model_selection import KFold, ShuffleSplit

# %%
# Test de MP data
def score_classifier(dataset, classifier, labels, show_confusion=True):
    import numpy as np
    from sklearn.model_selection import KFold
    from sklearn.metrics import confusion_matrix, recall_score

    """
    Performs 3 random trainings/tests to build a confusion matrix and prints results with precision and recall scores.
    :param dataset: the dataset to work on
    :param classifier: the classifier to use
    :param labels: the labels used for training and validation
    :return:
    """

    kf = KFold(n_splits=3, random_state=50, shuffle=True)
    confusion_mat = np.zeros((2, 2))
    recall = 0
    
    for training_ids, test_ids in kf.split(dataset):
        training_set = dataset[training_ids]
        training_labels = labels[training_ids]
        test_set = dataset[test_ids]
        test_labels = labels[test_ids]
        classifier.fit(training_set, training_labels)
        predicted_labels = classifier.predict(test_set)
        confusion_mat += confusion_matrix(test_labels, predicted_labels)
        recall += recall_score(test_labels, predicted_labels)
        
    recall /= 3

    if show_confusion:
        print("MP data recall:", recall)
        fig, ax = plt.subplots()
        sns.heatmap(confusion_mat.astype(np.uint8), cbar=False, annot=True, fmt='d', ax=ax)
        plt.show()
        
    return recall

# %%
def evaluation(model):

    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    print(classification_report(y_test, y_pred))
    
    print(f"{10*"--"} Custom score function from MP DATA")
    print("Custom recall on Test data")
    score_classifier(X_test.to_numpy(), model, y_test.to_numpy())
    print(f"{30*"--"}")

    N, train_score, val_score = learning_curve(model, X_train, y_train, scoring="f1",
                                               cv=5, train_sizes=np.linspace(0.1,1,10))

    fig = plt.figure()
    plt.plot(N, train_score.mean(axis=1), label='train score')
    plt.plot(N, val_score.mean(axis=1), label='Validation score')
    plt.legend()
    plt.show()

# %%
evaluation(prep_step_model)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.65      0.49      0.56       100
#          1.0       0.73      0.84      0.78       165
#
#     accuracy                           0.71       265
#    macro avg       0.69      0.67      0.67       265
# weighted avg       0.70      0.71      0.70       265
#
# -------------------- Custom score function from MP DATA
# Custom recall on Test data
# MP data recall: 0.8537630525713942
# ------------------------------------------------------------

# %%
# feature_importance = pd.DataFrame(prep_step_model.feature_importances_, index=X_train.columns)

# %%
# fig, ax = plt.subplots(figsize=[12,5])
# feature_importance.plot.bar(fig=fig, ax=ax)

# %% [markdown]
# ## Premiere Modélisation

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import FunctionTransformer
from sklearn.compose import ColumnTransformer
from sklearn.cluster import KMeans

# %%
decisionTree = make_pipeline(scaler, DecisionTreeClassifier(max_depth=2, random_state=0)) 

randomForest = make_pipeline(scaler, RandomForestClassifier(max_depth=2, random_state=0)) 
adaBoost = make_pipeline(scaler, AdaBoostClassifier(random_state=0)) 

svm = make_pipeline(scaler, SVC(random_state=0))
knn = make_pipeline(scaler, KNeighborsClassifier())

gradBoost = make_pipeline(scaler, GradientBoostingClassifier(random_state=0))

# %%
list_of_models = [decisionTree, randomForest, gradBoost, adaBoost, svm, knn]
list_of_names = ["decisionTree", "randomForest", "gradBoost", "adaBoost", "svm", "knn"]

dict_of_models = dict(zip(list_of_names, list_of_models))

# %%
for model_name, model in dict_of_models.items():
    print(model_name)
    evaluation(model)
# Out:
# decisionTree
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.46      0.51       100
#          1.0       0.71      0.80      0.75       165
#
#     accuracy                           0.67       265
#    macro avg       0.65      0.63      0.63       265
# weighted avg       0.66      0.67      0.66       265
#
# -------------------- Custom score function from MP DATA
# Custom recall on Test data
# MP data recall: 0.9146780616492632
# ------------------------------------------------------------
# randomForest
#               precision    recall  f1-score   support
#
#          0.0       0.65      0.47      0.55       100
#          1.0       0.73      0.85      0.78       165
#
#     accuracy                           0.71       265
#    macro avg       0.69      0.66      0.66       265
# weighted avg       0.70      0.71      0.69       265
#
# -------------------- Custom score function from MP DATA
# Custom recall on Test data
# MP data recall: 0.8468036873200727
# ------------------------------------------------------------
# gradBoost
#               precision    recall  f1-score   support
#
#          0.0       0.66      0.49      0.56       100
#          1.0       0.73      0.85      0.79       165
#
#     accuracy                           0.71       265
#    macro avg       0.70      0.67      0.67       265
# weighted avg       0.71      0.71      0.70       265
#
# -------------------- Custom score function from MP DATA
# Custom recall on Test data
# MP data recall: 0.8288184727112234
# ------------------------------------------------------------
# adaBoost
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.49      0.55       100
#          1.0       0.73      0.83      0.78       165
#
#     accuracy                           0.70       265
#    macro avg       0.68      0.66      0.66       265
# weighted avg       0.69      0.70      0.69       265
#
# -------------------- Custom score function from MP DATA
# Custom recall on Test data
# MP data recall: 0.7697170312860481
# ------------------------------------------------------------
# svm
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.54      0.62       100
#          1.0       0.76      0.88      0.81       165
#
#     accuracy                           0.75       265
#    macro avg       0.74      0.71      0.72       265
# weighted avg       0.75      0.75      0.74       265
#
# -------------------- Custom score function from MP DATA
# Custom recall on Test data
# MP data recall: 0.8299138354749079
# ------------------------------------------------------------
# knn
#               precision    recall  f1-score   support
#
#          0.0       0.65      0.54      0.59       100
#          1.0       0.75      0.82      0.78       165
#
#     accuracy                           0.72       265
#    macro avg       0.70      0.68      0.69       265
# weighted avg       0.71      0.72      0.71       265
#
# -------------------- Custom score function from MP DATA
# Custom recall on Test data
# MP data recall: 0.769259627055059
# ------------------------------------------------------------

# %% [markdown]
# # Optimisation

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score, accuracy_score
from sklearn.metrics import precision_recall_curve, f1_score, recall_score

# %%
def optimize_and_evaluate(model_to_optimize, param_grid, X_train, y_train, X_test, y_test, evaluation_fn, scoring_method="f1"):
    
    grid_search = GridSearchCV(model_to_optimize, param_grid=param_grid, cv=5, scoring=scoring_method)
    grid_search.fit(X_train, y_train)
    
    best_estimator = grid_search.best_estimator_

    evaluation_fn(best_estimator)
    
    y_pred = best_estimator.predict(X_test)
    f1 = f1_score(y_test, y_pred)
        
    return best_estimator, f1

# %% [markdown]
# ## DecisionTree

# %%
# decisionTree.get_params()

# %%
params_to_optimize = {"decisiontreeclassifier__max_depth":[1,2,3,4,5], 
                      # "pca__n_components":[2,3,4,5,6],
                      'decisiontreeclassifier__min_samples_leaf': [10, 20, 30],
                      'decisiontreeclassifier__min_samples_split': [20, 30, 40]}

best_decisionTree_estimator, f1 = optimize_and_evaluate(
    model_to_optimize=decisionTree,
    param_grid=params_to_optimize,
    X_train=X_train,
    y_train=y_train,
    X_test=X_test,
    y_test=y_test,
    evaluation_fn=evaluation,
)

print("Best estimator")
display(best_decisionTree_estimator)
print("F1 score on Test data: ", f1)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.46      0.51       100
#          1.0       0.71      0.80      0.75       165
#
#     accuracy                           0.67       265
#    macro avg       0.65      0.63      0.63       265
# weighted avg       0.66      0.67      0.66       265
#
# -------------------- Custom score function from MP DATA
# Custom recall on Test data
# MP data recall: 0.9146780616492632
# ------------------------------------------------------------
# Best estimator
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('decisiontreeclassifier',
#                  DecisionTreeClassifier(max_depth=2, min_samples_leaf=10,
#                                         min_samples_split=20,
#                                         random_state=0))])
# F1 score on Test data:  0.8131313131313131

# %%
y_pred = best_decisionTree_estimator.predict(X_test)

# %%
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, cbar=False, fmt='d')
# Out:
# <Axes: >

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.720754716981132

# %%
f1_score(y_test, y_pred)
# Out:
# 0.8131313131313131

# %%
recall_score(y_test, y_pred, pos_label=1)
# Out:
# 0.9757575757575757

# %% [markdown]
# ## RandomForest

# %%
# randomForest.get_params()

# %%
params_to_optimize = {"randomforestclassifier__n_estimators":[100, 200, 300], 
                      "randomforestclassifier__max_depth":[1,2,3], 
                      'randomforestclassifier__min_samples_leaf': [10, 20, 30],
                      'randomforestclassifier__min_samples_split': [20, 30, 40]}

best_randomForest_estimator, f1 = optimize_and_evaluate(
    model_to_optimize=randomForest,
    param_grid=params_to_optimize,
    X_train=X_train,
    y_train=y_train,
    X_test=X_test,
    y_test=y_test,
    evaluation_fn=evaluation,
)

print("Best estimator")
display(best_randomForest_estimator)
print("F1 score on Test data: ", f1)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.30      0.40       100
#          1.0       0.68      0.88      0.77       165
#
#     accuracy                           0.66       265
#    macro avg       0.64      0.59      0.58       265
# weighted avg       0.65      0.66      0.63       265
#
# -------------------- Custom score function from MP DATA
# Custom recall on Test data
# MP data recall: 0.8953527328899722
# ------------------------------------------------------------
# Best estimator
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(max_depth=1, min_samples_leaf=10,
#                                         min_samples_split=20, n_estimators=300,
#                                         random_state=0))])
# F1 score on Test data:  0.8191489361702128

# %%
y_pred = best_randomForest_estimator.predict(X_test)

# %%
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, cbar=False, fmt='d')
# Out:
# <Axes: >

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7433962264150943

# %%
f1_score(y_test, y_pred)
# Out:
# 0.8191489361702128

# %%
recall_score(y_test, y_pred)
# Out:
# 0.9333333333333333

# %% [markdown]
# ## SVM

# %%
# svm.get_params()

# %%
params_to_optimize = {
    "svc__C": [0.01, 0.1, 1, 10], 
}

best_svm_estimator, f1 = optimize_and_evaluate(
    model_to_optimize=svm,
    param_grid=params_to_optimize,
    X_train=X_train,
    y_train=y_train,
    X_test=X_test,
    y_test=y_test,
    evaluation_fn=evaluation,
)

print("Best estimator")
display(best_svm_estimator)
print("F1 score on Test data: ", f1)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.54      0.62       100
#          1.0       0.76      0.88      0.81       165
#
#     accuracy                           0.75       265
#    macro avg       0.74      0.71      0.72       265
# weighted avg       0.75      0.75      0.74       265
#
# -------------------- Custom score function from MP DATA
# Custom recall on Test data
# MP data recall: 0.8299138354749079
# ------------------------------------------------------------
# Best estimator
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svc', SVC(C=1, random_state=0))])
# F1 score on Test data:  0.8263473053892215

# %% [markdown]
# ### Precision-Recall curve

# %%
precision_svm, recal_svm, thresholds_svm = precision_recall_curve(y_test, best_svm_estimator.decision_function(X_test))

# %%
import matplotlib.pyplot as plt
plt.plot(thresholds_svm, precision_svm[:-1], label='precision')
plt.plot(thresholds_svm, recal_svm[:-1], label='recal')
plt.legend()

threshold = thresholds_svm[precision_svm[:-1] < recal_svm[:-1]][-1]
plt.axvline(threshold,c='k', linestyle=':')
plt.title("Precision-Recall function")
# Out:
# Text(0.5, 1.0, 'Precision-Recall function')

# %%
def final_model(model, X, threshold):
    return model.decision_function(X) > threshold

# %%
y_pred = final_model(best_svm_estimator, X_test, threshold)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7811320754716982

# %%
f1_score(y_test, y_pred)
# Out:
# 0.8242424242424242

# %%
recall_score(y_test, y_pred)
# Out:
# 0.8242424242424242

# %%
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# ## AdaBoost

# %%
adaBoost.get_params()
# Out:
# {'memory': None,
#  'steps': [('standardscaler', StandardScaler()),
#   ('adaboostclassifier', AdaBoostClassifier(random_state=0))],
#  'verbose': False,
#  'standardscaler': StandardScaler(),
#  'adaboostclassifier': AdaBoostClassifier(random_state=0),
#  'standardscaler__copy': True,
#  'standardscaler__with_mean': True,
#  'standardscaler__with_std': True,
#  'adaboostclassifier__algorithm': 'SAMME.R',
#  'adaboostclassifier__estimator': None,
#  'adaboostclassifier__learning_rate': 1.0,
#  'adaboostclassifier__n_estimators': 50,
#  'adaboostclassifier__random_state': 0}

# %%
params_to_optimize = {"adaboostclassifier__learning_rate":[0.1, 0.2, 0.5, 1], 
                      "adaboostclassifier__n_estimators": [100,200,400],
                     }

best_adaBoost_estimator, f1 = optimize_and_evaluate(
    model_to_optimize=adaBoost,
    param_grid=params_to_optimize,
    X_train=X_train,
    y_train=y_train,
    X_test=X_test,
    y_test=y_test,
    evaluation_fn=evaluation,
)

print("Best estimator")
display(best_adaBoost_estimator)
print("F1 score on Test data: ", f1)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.48      0.56       100
#          1.0       0.73      0.86      0.79       165
#
#     accuracy                           0.72       265
#    macro avg       0.70      0.67      0.68       265
# weighted avg       0.71      0.72      0.70       265
#
# -------------------- Custom score function from MP DATA
# Custom recall on Test data
# MP data recall: 0.8422797989828773
# ------------------------------------------------------------
# Best estimator
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('adaboostclassifier',
#                  AdaBoostClassifier(learning_rate=0.1, n_estimators=100,
#                                     random_state=0))])
# F1 score on Test data:  0.8621700879765396

# %% [markdown]
# ### Precision-Recall curve

# %%
from sklearn.metrics import precision_recall_curve, f1_score, recall_score

# %%
precision_ada, recal_ada, thresholds_ada = precision_recall_curve(y_test, best_adaBoost_estimator.decision_function(X_test))

# %%
import matplotlib.pyplot as plt
plt.plot(thresholds_ada, precision_ada[:-1], label='precision')
plt.plot(thresholds_ada, recal_ada[:-1], label='recal')
plt.legend()

threshold = thresholds_ada[precision_ada[:-1] < recal_ada[:-1]][-1]
plt.axvline(threshold,c='k', linestyle=':')
plt.title("Precision-Recall function")
# Out:
# Text(0.5, 1.0, 'Precision-Recall function')

# %%
def final_model(model, X, threshold=0):
    return model.decision_function(X) > threshold

# %%
y_pred = final_model(best_adaBoost_estimator, X_test, threshold=threshold)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8188679245283019

# %%
f1_score(y_test, y_pred)
# Out:
# 0.8545454545454545

# %%
recall_score(y_test, y_pred)
# Out:
# 0.8545454545454545

# %%
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# ## gradBoost

# %%
# gradBoost.get_params()

# %%
params_to_optimize = {"gradientboostingclassifier__learning_rate":[0.01, 0.05, 0.1], 
                      "gradientboostingclassifier__n_estimators": [100,200],
                      'gradientboostingclassifier__min_samples_leaf': [10, 20, 30],
                      'gradientboostingclassifier__min_samples_split': [20, 30, 40]}

best_gradBoost_estimator, f1 = optimize_and_evaluate(
    model_to_optimize=gradBoost,
    param_grid=params_to_optimize,
    X_train=X_train,
    y_train=y_train,
    X_test=X_test,
    y_test=y_test,
    evaluation_fn=evaluation,
)

print("Best estimator")
display(best_gradBoost_estimator)
print("F1 score on Test data: ", f1)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.32      0.44       100
#          1.0       0.69      0.91      0.78       165
#
#     accuracy                           0.69       265
#    macro avg       0.68      0.61      0.61       265
# weighted avg       0.69      0.69      0.65       265
#
# -------------------- Custom score function from MP DATA
# Custom recall on Test data
# MP data recall: 0.9085853570461316
# ------------------------------------------------------------
# Best estimator
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('gradientboostingclassifier',
#                  GradientBoostingClassifier(learning_rate=0.01,
#                                             min_samples_leaf=10,
#                                             min_samples_split=20,
#                                             random_state=0))])
# F1 score on Test data:  0.8532608695652174

# %% [markdown]
# ### Precision-Recall curve

# %%
precision_gradBoost, recal_gradBoost, thresholds_gradBoost = precision_recall_curve(y_test, best_gradBoost_estimator.decision_function(X_test))

# %%
import matplotlib.pyplot as plt
plt.plot(thresholds_gradBoost, precision_gradBoost[:-1], label='precision')
plt.plot(thresholds_gradBoost, recal_gradBoost[:-1], label='recal')
plt.legend()


threshold = thresholds_gradBoost[precision_gradBoost[:-1] < recal_gradBoost[:-1]][-1]
plt.axvline(threshold, c='k', linestyle=':')
plt.title("Precision-Recall function")
# Out:
# Text(0.5, 1.0, 'Precision-Recall function')

# %%
def final_model(model, X, threshold=0):
    return model.decision_function(X) > threshold

# %%
y_pred = final_model(best_gradBoost_estimator, X_test, threshold=threshold)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8075471698113208

# %%
f1_score(y_test, y_pred)
# Out:
# 0.8449848024316109

# %%
recall_score(y_test, y_pred)
# Out:
# 0.8424242424242424

# %%
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# ## KNN

# %%
# knn.get_params()

# %%
params_to_optimize = {
    "kneighborsclassifier__metric": ["minkowski", "euclidean", "manhattan"], 
    "kneighborsclassifier__n_neighbors": [2, 3, 4, 5, 6, 7, 8, 9, 10],
}

best_knn_estimator, f1 = optimize_and_evaluate(
    model_to_optimize=knn,
    param_grid=params_to_optimize,
    X_train=X_train,
    y_train=y_train,
    X_test=X_test,
    y_test=y_test,
    evaluation_fn=evaluation,
)

print("Best estimator")
display(best_knn_estimator)
print("F1 score on Test data: ", f1)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.66      0.54      0.59       100
#          1.0       0.75      0.83      0.79       165
#
#     accuracy                           0.72       265
#    macro avg       0.70      0.69      0.69       265
# weighted avg       0.71      0.72      0.71       265
#
# -------------------- Custom score function from MP DATA
# Custom recall on Test data
# MP data recall: 0.8407109827169409
# ------------------------------------------------------------
# Best estimator
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='manhattan', n_neighbors=9))])
# F1 score on Test data:  0.8106508875739645

# %%
y_pred = best_knn_estimator.predict(X_test)

# %%
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, cbar=False, fmt='d')
# Out:
# <Axes: >

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7584905660377359

# %%
f1_score(y_test, y_pred)
# Out:
# 0.8106508875739645

# %%
recall_score(y_test, y_pred)
# Out:
# 0.8303030303030303

# %% [markdown]
# # Benchmarking Best models

# %%
from sklearn.model_selection import cross_val_score
from tqdm import tqdm

summary_performances = pd.DataFrame(columns=["Model name", "Recall - Train", "F1 - Train", "Accuracy - Train", 
                                             "Recall - Test", "F1 - Test", "Accuracy - Test", "Decision boundary", "Threshold"])

def get_summary_performances(best_model_name, best_model, cv=5, decision_function=False, threshold_index=-1, return_pred=False):


    f1_train = cross_val_score(best_model, X_train, y_train, cv=cv, scoring='f1').mean() 
    acc_train = cross_val_score(best_model, X_train, y_train, cv=cv, scoring='accuracy').mean()
    recall_train = cross_val_score(best_model, X_train, y_train, cv=cv, scoring='recall').mean()

    
    th = None
    mp_data_test = None
    if not decision_function:
            y_pred = best_model.predict(X_test)
            f1_score_test = f1_score(y_test, y_pred) 
            acc_score_test = accuracy_score(y_test, y_pred)
            recall_score_test = recall_score(y_test, y_pred)
            th = np.nan
    else:
        try:
            precision, recall, thresholds = precision_recall_curve(y_test, best_model.decision_function(X_test))
            th = thresholds[precision[:-1] < recall[:-1]][threshold_index]
            y_pred = final_model(best_model, X_test, threshold=th)
            f1_score_test = f1_score(y_test, y_pred) 
            acc_score_test = accuracy_score(y_test, y_pred)
            recall_score_test = recall_score(y_test, y_pred)
            mp_data_test = np.nan

        
        except BaseException:
            f1_score_test = np.nan
            acc_score_test = np.nan
            recall_score_test = np.nan

    summary_performances.loc[len(summary_performances)] = [best_model_name, recall_train, f1_train, acc_train, recall_score_test, 
                                                           f1_score_test, acc_score_test, decision_function, th]
    
    
    if return_pred:
        return summary_performances, y_pred
        
    else:
        return summary_performances

# %%
list_of_best_models = [best_decisionTree_estimator, best_randomForest_estimator, best_gradBoost_estimator, 
                       best_adaBoost_estimator, best_svm_estimator, best_knn_estimator]

list_of_best_names = ["best_decisionTree_estimator", "best_randomForest_estimator", "best_gradBoost_estimator", 
                       "best_adaBoost_estimator", "best_svm_estimator", "best_knn_estimator"]

dict_of_best_models = dict(zip(list_of_best_names[:], list_of_best_models[:]))

# %%
for d in [False, True]:
    for name, model in dict_of_best_models.items():
        summary_performances = get_summary_performances(name, model, cv=5, decision_function=d, threshold_index=-1)

# %%
summary_performances
# Out:
#                      Model name  Recall - Train  F1 - Train  Accuracy - Train  \
# 0   best_decisionTree_estimator        0.831861    0.769150          0.690440
# 1   best_randomForest_estimator        0.865449    0.771120          0.680943
# 2      best_gradBoost_estimator        0.873083    0.783419          0.699946
# 3       best_adaBoost_estimator        0.824146    0.778026          0.708459
# 4            best_svm_estimator        0.827258    0.774038          0.699959
# 5            best_knn_estimator        0.793611    0.753452          0.678104
# 6   best_decisionTree_estimator        0.831861    0.769150          0.690440
# 7   best_randomForest_estimator        0.865449    0.771120          0.680943
# 8      best_gradBoost_estimator        0.873083    0.783419          0.699946
# 9       best_adaBoost_estimator        0.824146    0.778026          0.708459
# 10           best_svm_estimator        0.827258    0.774038          0.699959
# 11           best_knn_estimator        0.793611    0.753452          0.678104
#
#     Recall - Test  F1 - Test  Accuracy - Test  Decision boundary  Threshold
# 0        0.975758   0.813131         0.720755              False        NaN
# 1        0.933333   0.819149         0.743396              False        NaN
# 2        0.951515   0.853261         0.796226              False        NaN
# 3        0.890909   0.862170         0.822642              False        NaN
# 4        0.836364   0.826347         0.781132              False        NaN
# 5        0.830303   0.810651         0.758491              False        NaN
# 6             NaN        NaN              NaN               True        NaN
# 7             NaN        NaN              NaN               True        NaN
# 8        0.842424   0.844985         0.807547               True   0.253623
# 9        0.854545   0.854545         0.818868               True   0.012582
# 10       0.824242   0.824242         0.781132               True   0.021276
# 11            NaN        NaN              NaN               True        NaN

# %% [markdown]
# ## Best decision boundaries

# %%
list_of_best_models = [best_gradBoost_estimator, best_adaBoost_estimator, best_svm_estimator]
list_of_best_names = ["best_gradBoost_estimator", "best_adaBoost_estimator", "best_svm_estimator"]

dict_of_best_models = dict(zip(list_of_best_names, list_of_best_models))

acc_max = 0.8
rec_max = 0.92
f1_max = 0.85

for threshold_index in tqdm(np.arange(-40, -1, 2)):
    summary_performances = pd.DataFrame(columns=["Model name", "Recall - Train", "F1 - Train", "Accuracy - Train", 
                                             "Recall - Test", "F1 - Test", "Accuracy - Test", "Decision boundary", "Threshold"])
    for name, model in dict_of_best_models.items():
        summary_performances, y_pred = get_summary_performances(name, model, cv=5, decision_function=True, threshold_index=threshold_index, return_pred=True)
        condition = (summary_performances[["Recall - Test"]].iloc[-1] > rec_max)[0] & (summary_performances[["Accuracy - Test"]].iloc[-1] > acc_max)[0] & (summary_performances[["F1 - Test"]].iloc[-1] > f1_max)[0] 
        if condition:
            print("Conditions satisfied - threshold index =", threshold_index)
            sns.heatmap(confusion_matrix(y_test, y_pred), cbar=False, annot=True, fmt='d')
            plt.show()
            display(summary_performances.iloc[-1:])
# Out:
#  20%|████████▊                                   | 4/20 [00:22<01:29,  5.57s/it]
# Conditions satisfied - threshold index = -32
#                 Model name  Recall - Train  F1 - Train  Accuracy - Train  \
# 1  best_adaBoost_estimator        0.824146    0.778026          0.708459
#
#    Recall - Test  F1 - Test  Accuracy - Test  Decision boundary  Threshold
# 1       0.951515   0.860274         0.807547               True  -0.036178
#  25%|███████████                                 | 5/20 [00:27<01:23,  5.56s/it]
# Conditions satisfied - threshold index = -30
#                 Model name  Recall - Train  F1 - Train  Accuracy - Train  \
# 1  best_adaBoost_estimator        0.824146    0.778026          0.708459
#
#    Recall - Test  F1 - Test  Accuracy - Test  Decision boundary  Threshold
# 1       0.945455   0.859504         0.807547               True  -0.034852
#  30%|█████████████▏                              | 6/20 [00:33<01:18,  5.57s/it]
# Conditions satisfied - threshold index = -28
#                 Model name  Recall - Train  F1 - Train  Accuracy - Train  \
# 1  best_adaBoost_estimator        0.824146    0.778026          0.708459
#
#    Recall - Test  F1 - Test  Accuracy - Test  Decision boundary  Threshold
# 1       0.945455   0.864266         0.815094               True  -0.033131
#  35%|███████████████▍                            | 7/20 [00:39<01:12,  5.60s/it]
# Conditions satisfied - threshold index = -26
#                 Model name  Recall - Train  F1 - Train  Accuracy - Train  \
# 1  best_adaBoost_estimator        0.824146    0.778026          0.708459
#
#    Recall - Test  F1 - Test  Accuracy - Test  Decision boundary  Threshold
# 1       0.939394    0.86351         0.815094               True  -0.030606
#  40%|█████████████████▌                          | 8/20 [00:44<01:06,  5.58s/it]
# Conditions satisfied - threshold index = -24
#                 Model name  Recall - Train  F1 - Train  Accuracy - Train  \
# 1  best_adaBoost_estimator        0.824146    0.778026          0.708459
#
#    Recall - Test  F1 - Test  Accuracy - Test  Decision boundary  Threshold
# 1       0.933333   0.862745         0.815094               True   -0.02762
#  45%|███████████████████▊                        | 9/20 [00:50<01:01,  5.56s/it]
# Conditions satisfied - threshold index = -22
#                 Model name  Recall - Train  F1 - Train  Accuracy - Train  \
# 1  best_adaBoost_estimator        0.824146    0.778026          0.708459
#
#    Recall - Test  F1 - Test  Accuracy - Test  Decision boundary  Threshold
# 1       0.921212   0.856338         0.807547               True  -0.025973
#  50%|█████████████████████▌                     | 10/20 [00:56<00:56,  5.70s/it]
# Conditions satisfied - threshold index = -20
#                 Model name  Recall - Train  F1 - Train  Accuracy - Train  \
# 1  best_adaBoost_estimator        0.824146    0.778026          0.708459
#
#    Recall - Test  F1 - Test  Accuracy - Test  Decision boundary  Threshold
# 1       0.921212    0.86119         0.815094               True  -0.019283
#  65%|███████████████████████████▉               | 13/20 [01:13<00:40,  5.80s/it]
# Conditions satisfied - threshold index = -14
#                  Model name  Recall - Train  F1 - Train  Accuracy - Train  \
# 0  best_gradBoost_estimator        0.873083    0.783419          0.699946
#
#    Recall - Test  F1 - Test  Accuracy - Test  Decision boundary  Threshold
# 0       0.927273   0.854749         0.803774               True    0.08488
#  70%|██████████████████████████████             | 14/20 [01:19<00:35,  5.86s/it]
# Conditions satisfied - threshold index = -12
#                  Model name  Recall - Train  F1 - Train  Accuracy - Train  \
# 0  best_gradBoost_estimator        0.873083    0.783419          0.699946
#
#    Recall - Test  F1 - Test  Accuracy - Test  Decision boundary  Threshold
# 0       0.927273   0.859551         0.811321               True   0.106853
# 100%|███████████████████████████████████████████| 20/20 [01:54<00:00,  5.70s/it]

# %% [markdown]
# # Modele choisi:
# #### On a choisi le modele qui retourne la meilleur Recall avec un score F1 > 0.85 et une accuracy > 0.8: Un AdaBoost (Threshold de la fonc de decision = -0.033131)

# %%
import pickle

# %%
filename = './adaBoost_best_model.sav'
pickle.dump(best_adaBoost_estimator, open(filename, 'wb'))
threshold = -0.033131

loaded_model = pickle.load(open(filename, 'rb'))
prediction = final_model(loaded_model, X_test, threshold)

print("Accuracy:", accuracy_score(y_test, prediction))
print("Recall:", recall_score(y_test, prediction))
print("F1:", f1_score(y_test, prediction))
# Out:
# Accuracy: 0.8150943396226416
# Recall: 0.9454545454545454
# F1: 0.8642659279778393

# %%
index = 3
artificial_data = X_test.reset_index(drop=True).iloc[index:index+1]
display(artificial_data)
real_value = y_test.reset_index(drop=True)[index]
print("Real:", real_value)
print("Prediction:", final_model(loaded_model, artificial_data, threshold)[0]*1)
# Out:
#    GP   MIN  PTS  FGA   FG%  3P Made  3PA   3P%  FTA   FT%  OREB  DREB  REB  \
# 3  24  17.5  5.2  4.6  39.1      0.4  1.1  38.5  1.7  72.5   0.1   1.0  1.1
#
#    AST  BLK  TOV
# 3  2.9  0.1  1.0
# Real: 0.0
# Prediction: 0

# %%
index = 4
artificial_data = X_test.reset_index(drop=True).iloc[index:index+1]
display(artificial_data)
real_value = y_test.reset_index(drop=True)[index]
print("Real:", real_value)
print("Prediction:", final_model(loaded_model, artificial_data, threshold)[0]*1)
# Out:
#    GP  MIN  PTS  FGA   FG%  3P Made  3PA  3P%  FTA   FT%  OREB  DREB  REB  \
# 4  55  9.7  1.7  1.3  47.9      0.0  0.0  0.0  0.7  68.3   0.7   1.2  1.9
#
#    AST  BLK  TOV
# 4  0.2  1.1  0.3
# Real: 1.0
# Prediction: 1

# %%
index = 5
artificial_data = X_test.reset_index(drop=True).iloc[index:index+1]
real_value = y_test.reset_index(drop=True)[index]
display(artificial_data)
print("Real:", real_value)
print("Prediction:", final_model(loaded_model, artificial_data, threshold)[0]*1)
# Out:
#    GP   MIN  PTS  FGA   FG%  3P Made  3PA   3P%  FTA   FT%  OREB  DREB  REB  \
# 5  37  10.9  3.9  4.4  29.8      0.2  0.8  23.3  1.7  69.4   0.2   0.7  0.9
#
#    AST  BLK  TOV
# 5  1.8  0.1  1.4
# Real: 0.0
# Prediction: 0

# %%
index = 6
artificial_data = X_test.reset_index(drop=True).iloc[index:index+1]
real_value = y_test.reset_index(drop=True)[index]
display(artificial_data)
print("Real:", real_value)
print("Prediction:", final_model(loaded_model, artificial_data, threshold)[0]*1)
# Out:
#    GP   MIN   PTS   FGA   FG%  3P Made  3PA  3P%  FTA   FT%  OREB  DREB  REB  \
# 6  82  35.6  18.9  15.3  49.1      0.0  0.0  0.0  5.4  71.6   3.3   5.9  9.3
#
#    AST  BLK  TOV
# 6  1.4  1.5  3.0
# Real: 1.0
# Prediction: 1

# %% [markdown]
# ---
